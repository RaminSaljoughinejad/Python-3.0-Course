# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]


plt.plot(x, y)

plt.axis([0, 6, 0, 20])

plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y, 'ro')

plt.axis([0, 6, 0, 20])

plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y, 'r--')

plt.axis([0, 6, 0, 20])

plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y, 'bs')

plt.axis([0, 6, 0, 20])

plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y, 'g^')

plt.axis([0, 6, 0, 20])

plt.show()
