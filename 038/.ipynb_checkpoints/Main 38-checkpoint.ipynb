# %% [markdown]
# # <span style='color:green;'>Exercise 038</span>
# <span style='color:red'>More into Exception Handling</span><br><br>
# <span>Other Useful Exceptions</span><br>
# <span style='color:brown;'>----------> NameError</span><br>
# <span style='color:brown;'>----------> IndexError</span><br>
# <span style='color:red;'>You will learn about other exceptions later.</span><br>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc17d851ef81> in <module>
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
my_num = [1,2,3]
print(my_num[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-666b707e4f13> in <module>
#       1 my_num = [1,2,3]
# ----> 2 print(my_num[3])
#
# IndexError: list index out of range
