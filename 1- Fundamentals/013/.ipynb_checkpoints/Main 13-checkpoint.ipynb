# %% [markdown]
# # <span style='color:green;'>Exercise 013</span>
# <span style='color:red'>Variables and Naming Rules</span>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
x = 2
print(x)
# Out:
# 2

# %%
y = x + 2
print(y)
# Out:
# 4

# %%
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c01ac3f50fdc> in <module>
# ----> 1 print(z)
#
# NameError: name 'z' is not defined

# %% [markdown]
# #### Python is a case sensitive programming language

# %%
Firstname = "Reza"
firstname = "Mitra"
print(Firstname)
print(firstname)
# Out:
# Reza
# Mitra

# %% [markdown]
# #### Naming Rules
# The only characters that are allowed are <span style='color:red'>letters</span>, <span style='color:red'>numbers</span>, and <span style='color:red'>underscores</span>. Also, they can't start with numbers.

# %%
my_var_x = 25

# %%
123abc = 4
# Out:
#   File "<ipython-input-6-2fab0a07edd6>", line 1
#     123abc = 4
#          ^
# SyntaxError: invalid syntax

# %%
x y = 5
# Out:
#   File "<ipython-input-7-0ddd75215315>", line 1
#     x y = 5
#       ^
# SyntaxError: invalid syntax
