# %% [markdown]
# # <span style='color:green;'>Exercise 049</span>
# <span style='color:red'>More Types</span><br><br>
# <span>Tuples</span><br>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
breakfast = ("egg", "bread", "honey", "milk", "tea", "coffee")

print(breakfast[0])
print(breakfast[3])
print(breakfast[5])
# Out:
# egg
# milk
# coffee

# %%
print(breakfast[7])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-6e716a51e593> in <module>
# ----> 1 print(breakfast[7])
#
# IndexError: tuple index out of range

# %%
breakfast[3] = "chocolate-milk"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-3966621ca13b> in <module>
# ----> 1 breakfast[3] = "chocolate-milk"
#
# TypeError: 'tuple' object does not support item assignment

# %%
dinner = "pizza", "burger", "pasta", "hotdog", "cheese-sandwich"

print(dinner[2])
# Out:
# pasta

# %%
lunch = ()

lunch[0] = "apple"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a20cf8cbdac3> in <module>
#       1 lunch = ()
#       2
# ----> 3 lunch[0] = "apple"
#
# TypeError: 'tuple' object does not support item assignment
