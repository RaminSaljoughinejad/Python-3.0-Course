# %% [markdown]
# # <span style='color:green;'>Exercise 020</span>
# <span style='color:red'>While Loop</span>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
x = 1
while x<5:
    print("Python 3.x")
    x+=1
# Out:
# Python 3.x
# Python 3.x
# Python 3.x
# Python 3.x

# %%
x = 1 
while x<5:
    print(str(x) + " : Python 3.x")
    x+=1
# Out:
# 1 : Python 3.x
# 2 : Python 3.x
# 3 : Python 3.x
# 4 : Python 3.x

# %%
x = 5
while x>0:
    print(x)
    x-=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# #### Infinite Loops

# %%
x = 5
while x>0:
    print(x)

# %% [markdown]
# ### Class-Assignment
# <br>
# <br>
# <span style='color:green;'>Write a program that takes 2 numbers from the user, then prints all the numbers between those two numbers.</span><br><br>
# <span style='color:green;align:right;float:right;' dir='rtl'>برنامه ای بنویسید که 2 عدد از کاربر دریافت و تمامی اعداد بین این دو عدد را چاپ کند.</span>

# %%
x = int(input("Please Enter a number: "))
y = int(input("Please Enter another number: "))

min = max = 0
if x>y:
    min = y + 1
    max = x
else:
    min = x + 1
    max = y

while min < max:
    print(min)
    min+=1
# Out:
# Please Enter a number: 2
# Please Enter another number: 9
# 3
# 4
# 5
# 6
# 7
# 8

# %% [markdown]
# # <span style='color:purple'>Please Check Assignments <a href='../Assignments/02/Assignment 02.ipynb'>02</a>, <a href='../Assignments/03/Assignment 03.ipynb'>03</a>, <a href='../Assignments/04/Assignment 04.ipynb'>04</a>, and <a href='../Assignments/05/Assignment 05.ipynb'>05</a></span>
