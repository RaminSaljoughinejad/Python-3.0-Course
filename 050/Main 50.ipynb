# %% [markdown]
# # <span style='color:green;'>Exercise 050</span>
# <span style='color:red'>More Types</span><br><br>
# <span>List Slices</span><br>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
Niki_E52 = [36, 43, 46, 45, 47, 39, 37, 38]

# %%
print(Niki_E52[2:6])
# Out:
# [46, 45, 47, 39]

# %%
print(Niki_E52[:6])
# Out:
# [36, 43, 46, 45, 47, 39]

# %%
print(Niki_E52[2:])
# Out:
# [46, 45, 47, 39, 37, 38]

# %%
finalMarks = {"John":18,"Tom":15,"Micheal":19,"Rose":13}

print(finalMarks[0:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7691a3bcf718> in <module>
#       1 finalMarks = {"John":18,"Tom":15,"Micheal":19,"Rose":13}
#       2
# ----> 3 print(finalMarks[0:2])
#
# TypeError: unhashable type: 'slice'

# %%
cars = ("BMW", "Toyota", "Benz")

print(cars[1:])
# Out:
# ('Toyota', 'Benz')
