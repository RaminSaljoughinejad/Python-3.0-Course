# %% [markdown]
# # <span style='color:green;'>Exercise 014</span>
# <span style='color:red'>In-Place Operators</span>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
x = 5
x = x + 2
print(x)
# Out:
# 7

# %%
x = 5
x += 2
print(x)
# Out:
# 7

# %%
x = 5
x -= 6
print(x)
# Out:
# -1

# %%
x = 5
x/=3
print(x)

x*=4
print(x)

x//=2
print(x)

x**=2
print(x)

x%=3
print(x)
# Out:
# 1.6666666666666667
# 6.666666666666667
# 3.0
# 9.0
# 0.0

# %%
x = "Python"
x += "Python"
print(x)
# Out:
# PythonPython

# %%
x = "Python"
x *= "Python"
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f81d92b9cd23> in <module>
#       1 x = "Python"
# ----> 2 x *= "Python"
#       3 print(x)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
x = "Python"
x *= 2
print(x)
# Out:
# PythonPython
