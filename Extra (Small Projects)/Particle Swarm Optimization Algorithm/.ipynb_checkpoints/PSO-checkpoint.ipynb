# %%
import random
import numpy as np

# %%
"""num_particles = int(input("Please Enter the Number of Particles: "))
num_epoches = int(input("Please Enter the Number of Epoches: "))
low_value= int(input("Please Enter the low value: "))
high_value = int(input("Please Enter the high value: "))"""

num_particles=20
num_epoches=3
low_value=-10
high_value=20

w= 0.5
c1 = 0.5
c2 = 0.9
target = 1

# %%
def fitness(x):
    return abs((x-2)%2)+1

# %%
def all_fitness(p_list):
    for i in range(num_particles):
        p_list[i][3] = fitness(p_list[i][0])
    return p_list

# %%
def population_creator(numP):
    particle_list = []
    for i in range(numP):
        x = random.randint(low_value,high_value)
        s = np.random.random()
        particle_list.append([x,s,x,fitness(x)])
    return particle_list

# %%
def pbest(p_list):
    for i in range(num_particles):
        if fitness(p_list[i][0])<p_list[i][2]:
            p_list[i][2]=p_list[i][0]
    return p_list

# %%
def g_best(p_list):
    for j in range(num_particles):
        for i in range(j,num_particles):
            if p_list[j][3]>p_list[i][3]:
                temp = p_list[j]
                p_list[j]=p_list[i]
                p_list[i]=temp
    return p_list

# %%
def update_positios(p_list):
    for i in range(0,num_particles):
        velocity = (
        ( w * p_list[i][1] ) +
        ((c1 * random.randint(0,1))*(p_list[i][2]-p_list[i][0])) +
        ((c2 * random.randint(0,1))*(p_list[0][0]-p_list[i][0]))
        )
        if fitness(p_list[i][2]>fitness(p_list[i][0]+velocity)):
            if p_list[i][0]+velocity < high_value and p_list[i][0]+velocity > low_value:
                p_list[i][0]=p_list[i][0]+velocity
        else:
            p_list[i][2]=0
    return p_list

# %%
particles = population_creator(num_particles)
particles = g_best(particles)
for i in particles:
        print(i)
# Out:
# [-8, 0.4494768141840869, -8, 1]
# [16, 0.7413053320255805, 16, 1]
# [12, 0.25972958169585736, 12, 1]
# [10, 0.71431005675365, 10, 1]
# [10, 0.2456959405058209, 10, 1]
# [16, 0.6280362695936951, 16, 1]
# [-4, 0.5276988338829581, -4, 1]
# [0, 0.20175821027815954, 0, 1]
# [10, 0.9296144149287243, 10, 1]
# [10, 0.5232782438888172, 10, 1]
# [-5, 0.6432984186158269, -5, 2]
# [9, 0.959059266956913, 9, 2]
# [-5, 0.41062870416598196, -5, 2]
# [17, 0.028134754988060506, 17, 2]
# [1, 0.7623373103554942, 1, 2]
# [5, 0.34208404602956277, 5, 2]
# [7, 0.5237243635690226, 7, 2]
# [13, 0.5254985984570496, 13, 2]
# [-9, 0.5532797702351971, -9, 2]
# [-7, 0.9483972258198166, -7, 2]

# %%
for zz in range(num_epoches):
    print("#",zz+1," :")
    particles = update_positios(particles)
    particles = all_fitness(particles)
    particles = pbest(particles)
    particles = g_best(particles)
    for i in particles:
        print(i)
    print("---------------------------------------------------------------------------------------")
# Out:
# # 1  :
# [-5.874887463364249, 0.2456959405058209, -5.874887463364249, 1.1251125366357506]
# [-7.775261592907957, 0.4494768141840869, -8, 1.224738407092044]
# [-5.7360963116727515, 0.5232782438888172, -5.7360963116727515, 1.2639036883272485]
# [-5.6678706427692305, 0.25972958169585736, -5.6678706427692305, 1.3321293572307695]
# [-5.640580405240335, 0.71431005675365, -5.640580405240335, 1.3594195947596646]
# [-7.621095548499563, 0.5532797702351971, -9, 1.3789044515004374]
# [-5.618205800138703, 0.959059266956913, -5.618205800138703, 1.3817941998612966]
# [10.464807207464363, 0.9296144149287243, 10.464807207464363, 1.4648072074643625]
# [-7.292421081534171, 0.41062870416598196, -5, 1.7075789184658294]
# [-5.28366805612313, 0.028134754988060506, -5.28366805612313, 1.7163319438768703]
# [-7.223536820707253, 0.9483972258198166, -7, 1.7764631792927474]
# [-7.133886016675682, 0.5276988338829581, -4, 1.8661139833243183]
# [-5.083717298820314, 0.6280362695936951, -5.083717298820314, 1.9162827011796857]
