# %% [markdown]
# # <span style='color:green;'>Exercise 057</span>
# <span style='color:red'>Functional Programming</span><br><br>
# <span>Map & Filter</span><br>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
def powerBy2(x):
    return x**2

myNumbers = [2,4,3,6,7]

for item in myNumbers:
    print(powerBy2(item))
# Out:
# 4
# 16
# 9
# 36
# 49

# %%
def powerBy2(x):
    return x**2

myNumbers = [2,4,3,6,7]

print(list(map(powerBy2,myNumbers)))
# Out:
# [4, 16, 9, 36, 49]

# %%
print(list(map(lambda x:x**2, myNumbers)))
# Out:
# [4, 16, 9, 36, 49]

# %%
def addHalf(x):
    return x+(x/2)

myNumbers = {"Tom":3, "Micheal":5, "John":7, "Rose":10}

print(list(map(addHalf, myNumbers)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d8365cf5291c> in <module>
#       4 myNumbers = {"Tom":3, "Micheal":5, "John":7, "Rose":10}
#       5
# ----> 6 print(list(map(addHalf, myNumbers)))
#
# <ipython-input-4-d8365cf5291c> in addHalf(x)
#       1 def addHalf(x):
# ----> 2     return x+(x/2)
#       3
#       4 myNumbers = {"Tom":3, "Micheal":5, "John":7, "Rose":10}
#       5
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
def addHalf(x):
    x = myNumbers[x]
    return x+(x/2)

myNumbers = {"Tom":3, "Micheal":5, "John":7, "Rose":10}

print(list(map(addHalf, myNumbers)))
# Out:
# [4.5, 7.5, 10.5, 15.0]

# %%
def addoneThird(x):
    return x+(x/3)

myNumbers = (2,5,3,6,9,15)

print(list(map(addoneThird,myNumbers)))
# Out:
# [2.6666666666666665, 6.666666666666667, 4.0, 8.0, 12.0, 20.0]

# %%
print(list(map(addoneThird,myNumbers[2:])))
# Out:
# [4.0, 8.0, 12.0, 20.0]
