# %% [markdown]
# # DELETING DATA

# %%
import mysql.connector

con1 = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="",
    database="mydatabase"
)
print(con1)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x000001E4755A3B38>

# %%
mycursor = con1.cursor()

sql = "DELETE FROM customers WHERE address = 'Mountain 21'"

mycursor.execute(sql)

con1.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
mycursor = con1.cursor()

sql = "DELETE FROM customers"

### mycursor.execute(sql)

con1.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# -1 record(s) deleted
