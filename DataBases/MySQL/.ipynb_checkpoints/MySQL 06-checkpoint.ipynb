# %% [markdown]
# # Alter Table

# %%
import mysql.connector

con1 = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="",
    database="mydatabase"
)
print(con1)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x0000021A94C36AC8>

# %%
mycursor = con1.cursor()

mycursor.execute("ALTER TABLE customers ADD COLUMN email VARCHAR(255)")
