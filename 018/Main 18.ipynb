# %% [markdown]
# # <span style='color:green;'>Exercise 018</span>
# <span style='color:red'>Boolian Logic</span>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
x = 2
y = 3

x == 2 and y == 3
# Out:
# True

# %%
x == 2 and y ==3 and x != y
# Out:
# True

# %%
if x>1 and y<5:
    print("OK")
# Out:
# OK

# %%
x==y or y<5
# Out:
# True

# %%
not x>y
# Out:
# True
