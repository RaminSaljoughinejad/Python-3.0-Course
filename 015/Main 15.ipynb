# %% [markdown]
# # <span style='color:green;'>Exercise 015</span>
# <span style='color:red'>Boolian & Comparison</span>
# <span style='display:none;'>Copyright All Rights Reserved Ramin Saljoughinejad</span>

# %%
my_bool_var = True
print(my_bool_var)
# Out:
# True

# %%
x = False
print(x)
# Out:
# False

# %%
1 > 2
# Out:
# False

# %%
2 <= 2
# Out:
# True

# %%
2.0 <= 2
# Out:
# True

# %%
1 != 1
# Out:
# False

# %%
3 == 3
# Out:
# True

# %%
"Python 2.0" != "Python 3.0"
# Out:
# True
