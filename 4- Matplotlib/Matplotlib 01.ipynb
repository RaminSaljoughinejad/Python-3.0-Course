# %%
import matplotlib.pyplot as plt

# %%
p1_x = 2
p1_y = 2

p2_x = 4
p2_y = 4

plt.plot([p1_x,p2_x],[p1_y,p2_y])

plt.show()

# %%
p1_x = 2
p1_y = 2

p2_x = 4
p2_y = 4

p3_x = 4
p3_y = 2

p4_x = 2
p4_y = 4

plt.plot([p1_x,p2_x,p3_x,p4_x,p1_x],[p1_y,p2_y,p3_y,p4_y,p1_y])

plt.show()

# %%
x = [1,2,3,1]
y = [5,9,7,5]

plt.plot(x,y)
plt.show()
